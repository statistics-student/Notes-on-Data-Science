# %%
import cv2
import numpy as np

# %%
import os

# %%
os.chdir('D:/Python笔记/练习类/爬虫/图片')

# %%
img1=cv2.imread('football.jpg',0)#不能有中文路径

# %%
cv2.namedWindow("Image",cv2.WINDOW_NORMAL)#创建窗口,后面参数为可调整窗口
cv2.imshow('Image',img1)#显示图像
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# %%
img =cv2.imread('football.jpg',0)
plt.imshow(img,cmap=None,interpolation = 'bicubic')
plt.xticks([]),plt.yticks([])  #to hide tick values on X and Y axis
plt.show()

# %%
# 图6-1中的矩阵
img = np.array([
    [[255, 0, 0], [0, 255, 0], [0, 0, 255]],
    [[255, 255, 0], [255, 0, 255], [0, 255, 255]],
    [[255, 255, 255], [128, 128, 128], [0, 0, 0]],
], dtype=np.uint8)

# 用matplotlib存储
plt.imsave('img_pyplot.jpg', img)

# 用OpenCV存储
cv2.imwrite('img_cv2.jpg', img)
# Out:
# True

# %%
plt.imshow(img1)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
